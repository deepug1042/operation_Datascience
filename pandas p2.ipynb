# %% [markdown]
# # Read Json to CSV

# %%
import pandas as pd
import numpy as np

# %%
data = r'C:\Users\Dell\Desktop\employee.json' #Reading the json file which i have created in notepad using key and values(multiple values in list)
# r--->It is used in the above case because the file path should be treated as raw string if 'r' is not used then we have to replace single slash with double back slash
# In orderwords using 'r' makes the file path cleaner and easier to write.
#with 'r'--> single back slash, without 'r'-->double back slash

# %%
df = pd.read_json(data) #using read_json built in function in pandas

# %%
df
# Out:
#   employee_name                email  \
# 0         Deepu  deepug104@gmail.com
#
#                                          job_profile
# 0  {'title1': 'Team lead', 'title2': 'HR', 'title...

# %%
df1 = pd.read_csv(r"C:\Users\Dell\Downloads\wine dataset\wine.csv",header = None ) #column name is replaced by numbers

# %%
df1
# Out:
#        0        1           2     3     4    5        6           7   \
# 0    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids
# 1       1    14.23        1.71  2.43  15.6  127      2.8        3.06
# 2       1     13.2        1.78  2.14  11.2  100     2.65        2.76
# 3       1    13.16        2.36  2.67  18.6  101      2.8        3.24
# 4       1    14.37        1.95   2.5  16.8  113     3.85        3.49
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 174     3    13.71        5.65  2.45  20.5   95     1.68         .61
# 175     3     13.4        3.91  2.48    23  102      1.8         .75
# 176     3    13.27        4.28  2.26    20  120     1.59         .69
# 177     3    13.17        2.59  2.37    20  120     1.65         .68
# 178     3    14.13         4.1  2.74  24.5   96     2.05         .76
#
#                        8        9          10    11    12       13
# 0    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# ...

# %%
df.to_csv('employee.csv') #to convert the dataframe into csv file

# %%
#convert json file to different json format
print(df.to_json())
#if you see above for every key value there is '0' along with it so ,to avoid this we use orient parameter setting to "records"
print(df.to_json(orient="records"))
#now the data is according to the values to the records
# Out:
# {"employee_name":{"0":"Deepu"},"email":{"0":"deepug104@gmail.com"},"job_profile":{"0":{"title1":"Team lead","title2":"HR","title3":"Student"}}}
# [{"employee_name":"Deepu","email":"deepug104@gmail.com","job_profile":{"title1":"Team lead","title2":"HR","title3":"Student"}}]

# %%
df.to_json(orient='split')
#it actually splits the key and corresponding value sepeartely
# Out:
# '{"columns":["employee_name","email","job_profile"],"index":[0],"data":[["Deepu","deepug104@gmail.com",{"title1":"Team lead","title2":"HR","title3":"Student"}]]}'

# %%
df1.to_json(orient="records")
#it is important to the key values in records
# Out:
# '[{"0":"Wine","1":"Alcohol","2":"Malic.acid","3":"Ash","4":"Acl","5":"Mg","6":"Phenols","7":"Flavanoids","8":"Nonflavanoid.phenols","9":"Proanth","10":"Color.int","11":"Hue","12":"OD","13":"Proline"},{"0":"1","1":"14.23","2":"1.71","3":"2.43","4":"15.6","5":"127","6":"2.8","7":"3.06","8":".28","9":"2.29","10":"5.64","11":"1.04","12":"3.92","13":"1065"},{"0":"1","1":"13.2","2":"1.78","3":"2.14","4":"11.2","5":"100","6":"2.65","7":"2.76","8":".26","9":"1.28","10":"4.38","11":"1.05","12":"3.4","13":"1050"},{"0":"1","1":"13.16","2":"2.36","3":"2.67","4":"18.6","5":"101","6":"2.8","7":"3.24","8":".3","9":"2.81","10":"5.68","11":"1.03","12":"3.17","13":"1185"},{"0":"1","1":"14.37","2":"1.95","3":"2.5","4":"16.8","5":"113","6":"3.85","7":"3.49","8":".24","9":"2.18","10":"7.8","11":".86","12":"3.45","13":"1480"},{"0":"1","1":"13.24","2":"2.59","3":"2.87","4":"21","5":"118","6":"2.8","7":"2.69","8":".39","9":"1.82","10":"4.32","11":"1.04","12":"2.93","13":"735"},{"0":"1","1":"14.2","2":"1.76"
# ...

# %% [markdown]
# # to_json-->helps to convert the dataframe to json files along with different formats.
# It is used to implement the model and convert it into json file to give it to the frontend developer

# %% [markdown]
# # Reading HTML contents
# -->It means that we are basically reading table from an html page
# -->It is also a type of web scrapping bt with respective table within a webpage

# %%
url = 'https://www.fdic.gov/bank/individual/failed/banklist.html'
hd = pd.read_html(url)
#the read_html picks the thead tags and grabs all the list of tables from the webpage

# %%
hd
# Out:
# [                               Bank Name               City          State  \
#  0  Republic First Bank dba Republic Bank       Philadelphia   Pennsylvania
#  1                          Citizens Bank           Sac City           Iowa
#  2               Heartland Tri-State Bank            Elkhart         Kansas
#  3                    First Republic Bank      San Francisco     California
#  4                         Signature Bank           New York       New York
#  5                    Silicon Valley Bank        Santa Clara     California
#  6                      Almena State Bank             Almena         Kansas
#  7             First City Bank of Florida  Fort Walton Beach        Florida
#  8                   The First State Bank      Barboursville  West Virginia
#  9                     Ericson State Bank            Ericson       Nebraska
#
#      Cert                 Aquiring Institution       Closing Date   Fund
# ...

# %%
type(hd)
# Out:
# list

# %%
hd[0]
#it doesnt care about the connceted links it will only display the records which are presented within the webpage
# Out:
#                                Bank Name               City          State  \
# 0  Republic First Bank dba Republic Bank       Philadelphia   Pennsylvania
# 1                          Citizens Bank           Sac City           Iowa
# 2               Heartland Tri-State Bank            Elkhart         Kansas
# 3                    First Republic Bank      San Francisco     California
# 4                         Signature Bank           New York       New York
# 5                    Silicon Valley Bank        Santa Clara     California
# 6                      Almena State Bank             Almena         Kansas
# 7             First City Bank of Florida  Fort Walton Beach        Florida
# 8                   The First State Bank      Barboursville  West Virginia
# 9                     Ericson State Bank            Ericson       Nebraska
#
#     Cert                 Aquiring Institution       Closing Date   Fund
# 0  27332    Fulton Bank, National Association     April 26, 2024  10546
# ...

# %%
#link used throudh wikepedia
#url = 'https://en.wikipedia.org/wiki/Mobile_country_code.html'
hd2 = pd.read_html('https://en.wikipedia.org/wiki/Mobile_country_code',match = 'Country',header = 0)

# %%
hd2
#match-->it matches the columns to the specified column
# Out:
# [     Mobile country code                                    Country ISO 3166  \
#  0                    289                                 A Abkhazia    GE-AB
#  1                    412                                Afghanistan       AF
#  2                    276                                    Albania       AL
#  3                    603                                    Algeria       DZ
#  4                    544  American Samoa (United States of America)       AS
#  ..                   ...                                        ...      ...
#  247                  452                                    Vietnam       VN
#  248                  543                        W Wallis and Futuna       WF
#  249                  421                                    Y Yemen       YE
#  250                  645                                   Z Zambia       ZM
#  251                  648                                   Zimbabwe       ZW
#
# ...

# %%
hd2[0]
# Out:
#      Mobile country code                                    Country ISO 3166  \
# 0                    289                                 A Abkhazia    GE-AB
# 1                    412                                Afghanistan       AF
# 2                    276                                    Albania       AL
# 3                    603                                    Algeria       DZ
# 4                    544  American Samoa (United States of America)       AS
# ..                   ...                                        ...      ...
# 247                  452                                    Vietnam       VN
# 248                  543                        W Wallis and Futuna       WF
# 249                  421                                    Y Yemen       YE
# 250                  645                                   Z Zambia       ZM
# 251                  648                                   Zimbabwe       ZW
#
# ...

# %% [markdown]
# # Reading Excel files
# ---> reading the excel file(.xlsx)
# --> we provide the parameter 'sheet'=(the specified sheet in the sheets are retrieved)
# --> by default it retrievs 0th sheet

# %%
df_excel = pd.read_excel("",sheet_name=)

# %% [markdown]
# # Pickling
# --> All pandas objects are equiped with to_pickle methods which use python's cpickle module to save data structures to disk using the pickle format.
# -->used to any type of files to pickle in machine learning

# %%
hd2.to_pickle('hd2')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 hd2.to_pickle('hd2')
#
# AttributeError: 'list' object has no attribute 'to_pickle'

# %%
# Note: suppose we have a huge dataset n the kernel is restarted again we no need to run all the dataset again instaed we can use pickle
